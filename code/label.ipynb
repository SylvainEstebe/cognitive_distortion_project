# %% [markdown]
# # Generate label

# %% [markdown]
# ## kmean

# %%
import spacy
import pandas as pd
import spacy
from spacy import displacy
import collections
import label
nlp = spacy.load("en_core_web_sm")
df = pd.read_csv("/Users/sylvainestebe/Code/nlp_project/cognitive_distortion_project/data/corpus_kmean.csv")
df2 = pd.read_csv("/Users/sylvainestebe/Code/nlp_project/cognitive_distortion_project/data/corpus_hdbscan_bayesian_optimisation.csv")

# %%
data = df[["thought","all-mpnet-base-v2 k-mean","all-MiniLM-L12-v2 k-mean","All-Distilroberta-v1 k-mean"]]
data
# Out:
#                                                thought  \
# 0    I almost failed in a subject. I have ruined ev...
# 1    If there aren't many people there, the party s...
# 2    I ate more than I planned, so I blew my diet c...
# 3    I did badly in a writing contest I entered. I ...
# 4    My boss pointed out an unintentional error in ...
# ..                                                 ...
# 917                I should have ordered a milder dish
# 918                         I should have been perfect
# 919       they should have reminded me before I forgot
# 920                   I shouldn't have changed my hair
# 921  I should have studied harder, or more efficien...
#
#      all-mpnet-base-v2 k-mean  all-MiniLM-L12-v2 k-mean  \
# 0                           1                        11
# 1                           3                         6
# 2                           8                        12
# 3                           1                        11
# ...

# %%
cluster_summary1 = apply_and_summarize_labels(data, 'all-mpnet-base-v2 k-mean')
cluster_summary2 = apply_and_summarize_labels(data, 'all-MiniLM-L12-v2 k-mean')
cluster_summary3 = apply_and_summarize_labels(data, 'All-Distilroberta-v1 k-mean')
cluster_summary = pd.DataFrame()

# %%
cluster_summary["label all-mpnet-base-v2"] = cluster_summary1["label"]
cluster_summary["all-mpnet-base-v2 k-mean"] = cluster_summary1["all-mpnet-base-v2 k-mean"]


cluster_summary["label all-MiniLM-L12-v2"] = cluster_summary2["label"]
cluster_summary["all-MiniLM-L12-v2 k-mean"] = cluster_summary2["all-MiniLM-L12-v2 k-mean"]

cluster_summary["label All-Distilroberta-v1"] = cluster_summary3["label"]
cluster_summary["All-Distilroberta-v1 k-mean"] = cluster_summary3["All-Distilroberta-v1 k-mean"]

# %%
cluster_summary.sort_index()
# Out:
#          label all-mpnet-base-v2  all-mpnet-base-v2 k-mean  \
# 0   got_boyfriend_friend_husband                         0
# 1        got_grade_writer_friend                         1
# 2         feel_thing_life_friend                         2
# 3      ordered_dish_party_people                         3
# 4         hate_essay_self_person                         4
# 5                  lose_job_work                         5
# 6        hate_joke_friend_parent                         6
# 7   like_thing_girlfriend_friend                         7
# 8     gained_thought_racing_diet                         8
# 9      thinks_time_sister_mother                         9
# 10            felt_job_work_boss                        10
# 11           going_friend_person                        11
# 12      going_thing_failure_time                        12
#
#            label all-MiniLM-L12-v2  all-MiniLM-L12-v2 k-mean  \
# 0   like_project_friend_girlfriend                         0
# ...

# %%
cluster_summary.to_csv("/Users/sylvainestebe/Code/nlp_project/cognitive_distortion_project/data/label_kmean.csv")

# %% [markdown]
# ## HDBSCAN

# %%
data2 = df2[["thought","all-mpnet-base-v2 hdbscan_bayesian_optimisation","all-MiniLM-L12-v2 hdbscan_bayesian_optimisation","All-Distilroberta-v1 hdbscan_bayesian_optimisation"]]
data2
# Out:
#                                                thought  \
# 0    Someone I trusted stole something valuable of ...
# 1                              She doesn't respect me.
# 2    My friend is ignoring his recently-deceased wife.
# 3                              he took me for granted!
# 4    We will not be able to complete the work that ...
# ..                                                 ...
# 917  Not having made rent and having to borrow mone...
# 918    I’m a loser I hate myself and I’m ready to die
# 919  People around me do not need my presence I'm w...
# 920  I realize that I still don’t have anyone who I...
# 921   People are always bullying me Everyone hates me
#
#      all-mpnet-base-v2 hdbscan_bayesian_optimisation  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# ...

# %%
cluster_summary1_hd = apply_and_summarize_labels(data2, 'all-mpnet-base-v2 hdbscan_bayesian_optimisation')
cluster_summary2_hd = apply_and_summarize_labels(data2, 'all-MiniLM-L12-v2 hdbscan_bayesian_optimisation')
cluster_summary3_hd = apply_and_summarize_labels(data2, 'All-Distilroberta-v1 hdbscan_bayesian_optimisation')
cluster_summary_hd = pd.DataFrame()
cluster_summary_hd2 = pd.DataFrame()

# %%
cluster_summary_hd["label all-MiniLM-L12-v2 hdbscan_bayesian_optimisation"] = cluster_summary2_hd["label"]
cluster_summary_hd["all-MiniLM-L12-v2 hdbscan_bayesian_optimisation"] = cluster_summary2_hd["all-MiniLM-L12-v2 hdbscan_bayesian_optimisation"]

cluster_summary_hd2["label All-Distilroberta-v1 hdbscan_bayesian_optimisation"] = cluster_summary3_hd["label"]
cluster_summary_hd2["All-Distilroberta-v1 hdbscan_bayesian_optimisation"] = cluster_summary3_hd["All-Distilroberta-v1 hdbscan_bayesian_optimisation"]

# %%
cluster_summary_hd.to_csv("/Users/sylvainestebe/Code/nlp_project/cognitive_distortion_project/data/label_hdbscan_all-miniLM.csv")
cluster_summary_hd2.to_csv("/Users/sylvainestebe/Code/nlp_project/cognitive_distortion_project/data/label_hdbscan_roberta.csv")
